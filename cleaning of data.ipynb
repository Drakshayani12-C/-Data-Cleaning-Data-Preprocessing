# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\draksha\Downloads\Titanic-Dataset (2).csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#tail
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#shape
df.shape
# Out:
# (891, 12)

# %%
#info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# find missing value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#indentifying garbage value
for i in df.select_dtypes(include= "object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# Name
# Dooley, Mr. Patrick                                    1
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
#                                                       ..
# Hewlett, Mrs. (Mary D Kingcome)                        1
# Vestrom, Miss. Hulda Amanda Adolfina                   1
# Andersson, Mr. Anders Johan                            1
# Saundercock, Mr. William Henry                         1
# Bonnell, Miss. Elizabeth                               1
# Name: count, Length: 891, dtype: int64
# ******************************
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# ******************************
# Ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# ...

# %%
#descriptive statistics
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include= "object")
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
# Plot histogram for all numerical columns
for i in df.select_dtypes(include="number").columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df, x=i, kde=True, bins=30)
    plt.title(f'Distribution of {i}')
    plt.xlabel(i)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# Boxplot for each numeric column to detect outliers
for i in df.select_dtypes(include="number").columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df, y=i)
    plt.title(f'Boxplot of {i}')
    plt.tight_layout()
    plt.show()

# %%
# Scatterplots of selected features vs Fare (for example)
columns = ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch']

for i in columns:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(data=df, x=i, y='Fare')
    plt.title(f'{i} vs Fare')
    plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#correlation with the heatmap to interpret the relation and multicolliniarity
df.select_dtypes(include="number").corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Calculate the correlation matrix
s = df.corr(numeric_only=True)  # s is now defined

# %%
# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(s, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
for i in ["Age", "Cabin"]:
    print(i)  # or any logic you want to apply
# Out:
# Age
# Cabin

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values with median for selected columns
for i in ["Age", "Fare"]:
    df[i].fillna(df[i].median(), inplace=True)

# Import and initialize the KNNImputer
from sklearn.impute import KNNImputer
impute = KNNImputer()

# Apply KNNImputer to numerical columns
for i in df.select_dtypes(include="number").columns:
    df[i] = impute.fit_transform(df[[i]])

# Check remaining missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#decide weather to do outliers tratment or not, if do how?

# %%
def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1*5*iqr
    uw=q3+1*5*iqr
    return lw,uw

# %%
wisker(df['Age'])  # Or replace 'Age' with another numeric column
# Out:
# (np.float64(-43.0), np.float64(100.0))

# %%
# (Optional) Display the result
print(df[cols].describe())
# Out:
#               Age        Fare
# count  891.000000  891.000000
# mean    29.361582   29.133899
# std     13.019697   33.709294
# min      0.420000    0.000000
# 25%     22.000000    7.910400
# 50%     28.000000   14.454200
# 75%     35.000000   31.000000
# max     80.000000  146.448000

# %%
# List of numeric columns you want to clean
cols = ['Age', 'Fare']  # Add more if needed

# %%
# Apply wisker and replace outliers
for i in cols:
    lw, uw = wisker(df[i])
    df[i] = np.where(df[i] < lw, lw, df[i])
    df[i] = np.where(df[i] > uw, uw, df[i])

# %%
# Plot boxplots for cleaned columns
for i in cols:
    sns.boxplot(df[i])
    plt.title(f'Boxplot of {i}')
    plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# One-hot encoding on 'Sex' and 'Embarked' columns, drop first to avoid dummy trap
df = pd.get_dummies(data=df, columns=['Sex', 'Embarked'], drop_first=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  35.0    0.0    0.0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN      True       False        True
# 1          PC 17599  71.2833   C85     False       False       False
# 2  STON/O2. 3101282   7.9250   NaN     False       False        True
# ...
